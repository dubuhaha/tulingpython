# %% [markdown]
# # Tkinter项目实战-屏保
# ### 项目分析
# - 屏保可以自己启动，也可以手动启动
# - 一旦敲击键盘或者鼠标后，或者其它的引发事件则停止
# - 如果屏保是一幅画的话，则没有画框
# - 图形的动作是随机的，具有随机性，可能颜色、大小、运动方向、变形等
# - 整个屏保世界构成
#     - ScreenSaver:
#         - 需要一个canvas，大小与屏幕大小一致，没有边框
#         -
#     - Ball
#         - 颜色、大小、运动方向、变形等随机
#         - 球能动，可以被调用

# %%
import random
import tkinter

class RandomBall():
    '''
    定义运动球的类
    '''
    def __init__(self, canvas, scrnwidth, scrnheight):
        '''
        canvas: 画布，所有的内容动应该在画布上呈现出来，此处通过此变量传入
        scrnwidth/scrnheight：屏幕宽高
        '''
        # 球出现的初始位置要随机
        # xpos表示位置的x坐标
        self.xpos = random.randint(10, int(scrnwidth)-20)
        # ypos表示位置的y坐标
        self.ypos = random.randint(10, int(scnheight)-10)

        # 定义球的运动速度
        # 模拟运动：不断的擦掉原来的画，然后在一个新的地方再从新绘制
        # 此处xverlocity模拟x轴方向运动
        self.xverlocity = random.randint(4, 20)
        # 同理 yverlocity模拟的是y轴方向的运动
        self.yverlocity = random.randint(2,15)

        # 定义屏幕的大小
        self.scrnwidth = scrnwidth
        self.scnheight = scnheight

        # 球的大小随机，此处的大小用半径表示
        self.radius = random.randint(20, 120)

        # 定义颜色
        # RGB表示法：三个数字，每个数字值是0-255直接，表示红绿蓝三个颜色的大小
        # 在某些系统中，直接用英文单词表示也可以，比如red，green
        # 此处用lambda表达式
        c = lambda: random.randint(0,255)
        self.color = '#%02x%02x%02x'%(c(), c(), c())
        
    # 创建一个球
    def create_ball(self):
        '''
        用构造函数定义的变量值，在canvas上画一个球
        '''
        # tkinter没有画圆形函数，只有一个画椭圆函数
        # 只有一个画椭圆函数，画椭圆需要定义两个坐标
        # 在一个长方形内画椭圆，我们只需要定义长方形左上角和右下角就好
        
        
        

class ScreenSaver():
    '''
    定义屏保的类
    可以被启动
    '''

if __name__ == '__main__':
    # 启动屏保
